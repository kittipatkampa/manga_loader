# %%
# for python2
#import urllib
#for python3
import urllib.request

import os
import re
from bs4 import BeautifulSoup

# %%
class MangaLoader():

    def __init__(self, name=None, url_seed=None, start_page=None, stop_page=None, out_pdf=None):
        self.name = name
        self.url_seed = url_seed
        self.start_page = start_page
        self.stop_page = stop_page
        self.out_pdf = out_pdf

    def get_html_page(self, url, user_agent=None):
        if user_agent is None:
            user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/535.19 (KHTML, like Gecko) Ubuntu/12.04 Chromium/18.0.1025.168 Chrome/18.0.1025.168 Safari/535.19'
        try:
            html_obj = urllib.request.urlopen(urllib.request.Request(url, headers={'User-Agent': user_agent}))
            page = html_obj.read()
        except:
            print("the page probably does not exist")
            page = None
        return page

    def get_image_url(self, url):
        page = self.get_html_page(url)
        try:
            soup = BeautifulSoup(page, "lxml")

            if 'readms' in url:
                img_tag = soup.find(id="manga-page")
            elif 'mangareader' in url:
                img_tag = soup.find(id="imgholder").find(id="img")
            elif 'mangadoom' in url:
                img_tag = soup.findAll('img')[1]
            else:
                img_tag = None

            if img_tag != None:
                img_url = img_tag.get("src",None)
            else:
                img_url = None
        except:
            img_url = None
        return img_url

    def create_image_url_list(self, seed_url, start_page, stop_page, verbose=False):
        img_urls = []
        for i in range(start_page, stop_page+1):
            url = '{0}{1}'.format(seed_url,i)
            if verbose:
                print('retriving image from ',url,'...')
            img_urls.append( self.get_image_url(url) )
        self.img_urls = img_urls
        return img_urls

    def get_image_filename(self, img_url):
        for s in img_url.split('/'):
            if ('.jpg' in s) or ('.png' in s):
                return s
        return None

    def clean_img_filename(self, img_filename):
        import re
        if '.jpg' in img_filename:
            return re.sub('.jpg.*','.jpg', img_filename)
        elif '.png' in img_filename:
            return re.sub('.png.*','.png', img_filename)
        elif '.bmp' in img_filename:
            return re.sub('.bmp.*','.bmp', img_filename)
        else:
            return None

    def generate_image_filenames(self, img_urls):
        # remove None from the list
        img_urls = [u for u in img_urls if u is not None]
        img_urls = [u for u in img_urls if ('jpg' in u) or ('png' in u) or ('bmp' in u)]
        img_filenames = []
        for img_url in img_urls:
            img_filenames.append( self.clean_img_filename(self.get_image_filename(img_url)) )
        return img_filenames

    def download_images_from_urls(self, img_urls):
        # remove None from the list
        img_urls = [u for u in img_urls if u is not None]
        img_urls = [u for u in img_urls if ('jpg' in u) or ('png' in u) or ('bmp' in u)]
        # download images from urls
        cnt = 1
        for img_url in img_urls:
            img_filename = self.clean_img_filename(self.get_image_filename(img_url))
            os.system("wget -O {0} {1}".format(img_filename, img_url))
            cnt = cnt + 1
        return '{0} images downloaded'.format(cnt)

    def convert_images_to_pdf(self, img_filenames, output_filename):
        output_filename = output_filename.replace(' ','_')
        result = os.system("convert "+' '.join(img_filenames)+' '+output_filename)
        if result == 0:
            return 'the output pdf = {0}'.format(output_filename)
        else:
            return 'failed'

    def clean_up(self):
        # remove all the downloaded images
        for img_filename in self.img_filenames:
            os.system("rm {0}".format(img_filename))
        return 1

    def run(self, cleanup=True, verbose=True):
        self.img_urls = self.create_image_url_list( self.url_seed, self.start_page, self.stop_page, verbose)
        self.img_filenames = self.generate_image_filenames(self.img_urls)
        self.download_images_from_urls(self.img_urls)
        self.convert_images_to_pdf(self.img_filenames, self.out_pdf+'.pdf')
        if cleanup:
            self.clean_up()
        return 1


def send_mail_with_attachment(send_from, send_to, subject, text, gmail_user, gmail_pwd, files=None,
              server="127.0.0.1"):
    assert isinstance(send_to, list)

    msg = MIMEMultipart(
        From=send_from,
        To=COMMASPACE.join(send_to),
        Date=formatdate(localtime=True),
        Subject=subject
    )
    msg.attach(MIMEText(text))

    for f in files or []:
        with open(f, "rb") as fil:
            msg.attach(MIMEApplication(
                fil.read(),
                Content_Disposition='attachment; filename="%s"' % basename(f),
                Name=basename(f)
            ))

    try:
        smtp = smtplib.SMTP("smtp.gmail.com", 587)
        smtp.ehlo()
        smtp.starttls()
        smtp.login(gmail_user, gmail_pwd)
        smtp.sendmail(send_from, send_to, msg.as_string())
        smtp.close()
        print('successfully sent the mail')
    except:
        print("failed to send mail")



def get_credential(credential_file, account):
    '''
    Get the credential in order to send email.
    The credential file (e.g. '.credentials') is in the following json format:
    {"default": {
      "user": "user1"
      , "pwd": "yourcrazypassword"
      }
    , "projx": {
      "user": "user2"
      , "pwd": "anothercrazypassword"
      }
    }
    '''
    with open(credential_file) as cred:
        credentials = json.load(cred)

    return credentials[account]

# %%
# get credential for sending email to kindle
credential = get_credential('.credentials', 'default')

# setting parameters for your manga download
name = '20thCB'
start_page = 1
stop_page = 40
chapter_start = 32
chapter_end = 33

# loop to download your manga
for chapter in range(chapter_start, chapter_end+1):
    out_pdf = '20th Century Boys v{0}'.format(chapter)
    url_seed = 'http://www.mangareader.net/20th-century-boys/{0}/'.format(chapter)
    print("downloading vol.{0}".format(chapter))
    MangaLoader(name, url_seed, start_page, stop_page, out_pdf).run(cleanup=True, verbose=True)

    print("sending vol.{0}".format(chapter))
    send_mail_with_attachment(credential['from'], credential['kindle'], 'This is subject', 'body',
                              credential['user'], credential['pwd'],
                              ['/Users/kittipat.kampa/Dropbox/research/manga_loader/20th_Century_Boys_v{0}.pdf'.format(chapter)])
# Out:
# downloading vol.32
# retriving image from  http://www.mangareader.net/20th-century-boys/32/1 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/2 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/3 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/4 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/5 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/6 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/7 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/8 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/9 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/10 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/11 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/12 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/13 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/14 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/15 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/16 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/17 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/18 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/32/19 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/20 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/21 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/22 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/23 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/24 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/25 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/26 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/27 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/28 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/29 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/30 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/31 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/32 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/33 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/34 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/35 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/36 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/37 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/38 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/39 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/32/40 ...
# the page probably does not exist
# sending vol.32
# successfully sent the mail
# downloading vol.33
# retriving image from  http://www.mangareader.net/20th-century-boys/33/1 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/2 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/3 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/4 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/5 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/6 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/7 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/8 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/9 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/10 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/11 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/12 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/13 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/14 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/15 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/16 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/17 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/18 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/19 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/20 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/21 ...
# retriving image from  http://www.mangareader.net/20th-century-boys/33/22 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/23 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/24 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/25 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/26 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/27 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/28 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/29 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/30 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/31 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/32 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/33 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/34 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/35 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/36 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/37 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/38 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/39 ...
# the page probably does not exist
# retriving image from  http://www.mangareader.net/20th-century-boys/33/40 ...
# the page probably does not exist
# sending vol.33
# successfully sent the mail

# %%
# This just sends email only
def send_email(user, pwd, recipient, subject, body):
    import smtplib

    gmail_user = user
    gmail_pwd = pwd
    FROM = user
    TO = recipient if type(recipient) is list else [recipient]
    SUBJECT = subject
    TEXT = body

    # Prepare actual message
    message = """\From: %s\nTo: %s\nSubject: %s\n\n%s
    """ % (FROM, ", ".join(TO), SUBJECT, TEXT)
    try:
        server = smtplib.SMTP("smtp.gmail.com", 587)
        server.ehlo()
        server.starttls()
        server.login(gmail_user, gmail_pwd)
        server.sendmail(FROM, TO, message)
        server.close()
        print('successfully sent the mail')
    except:
        print("failed to send mail")

# %%
send_email(credential['user'], credential['pwd'], 'kittipat@gmail.com', 'subject of my email', 'body!')
# Out:
# successfully sent the mail
